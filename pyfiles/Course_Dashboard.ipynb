# %% [markdown]
# # Advanced Machine Learning — Course Dashboard
#
# **M&T Bank — Live Virtual Training**
#
# Use this page to reach every demo and lab notebook for the course. Click a link, it opens directly in Google Colab.
#
# ### How to use each notebook
# 1. Click the link for the notebook you want.
# 2. In Colab, go to **File → Save a copy in Drive**.
# 3. Work in your own copy — the original in the shared repo stays untouched.
# 4. Each notebook has a data-loading line commented out near the top. Your instructor will tell you the URL to paste there before you run the notebook (or it will already be filled in).
#
# ### About the Lab notebooks
# Each lab has two versions:
# - 📝 **Starter** — the exercise, for you to work through.
# - ✅ **Solution** — the completed version. It's provided from the start, so try the Starter first before opening it.
#
# ---

# %% [markdown]
# ## Block 2 — Demo: Dirty Data & Imputation
#
# - 📘 [Open Demo in Colab](https://colab.research.google.com/github/mithun-rk/mt-advml-course/blob/main/pyfiles/Day1_Block2_Demo_Dirty_Data_Imputation.ipynb)

# %% [markdown]
# ## Block 3 — Lab: Engineered Features & Denoising
#
# - 📝 [Open Lab (Starter) in Colab](https://colab.research.google.com/github/mithun-rk/mt-advml-course/blob/main/pyfiles/Day1_Block3_Lab_STARTER_Engineered_Features_Denoising.ipynb)
# - ✅ [Open Lab (Solution) in Colab](https://colab.research.google.com/github/mithun-rk/mt-advml-course/blob/main/pyfiles/Day1_Block3_Lab_SOLUTION_Engineered_Features_Denoising.ipynb)

# %% [markdown]
# ## Block 4 — Demo: Linear Models, Gradient Descent & Regularization
#
# - 📘 [Open Demo in Colab](https://colab.research.google.com/github/mithun-rk/mt-advml-course/blob/main/pyfiles/Day1_Block4_Demo_Linear_Models_GD_Regularization.ipynb)

# %% [markdown]
# ## Block 5 — Lab: SVM & k-Fold Cross-Validation
#
# - 📝 [Open Lab (Starter) in Colab](https://colab.research.google.com/github/mithun-rk/mt-advml-course/blob/main/pyfiles/Day1_Block5_Lab_STARTER_SVM_kFold_CV.ipynb)
# - ✅ [Open Lab (Solution) in Colab](https://colab.research.google.com/github/mithun-rk/mt-advml-course/blob/main/pyfiles/Day1_Block5_Lab_SOLUTION_SVM_kFold_CV.ipynb)

# %% [markdown]
# ## Block 6 — Demo: Evaluating Models — Metrics & Tuning
#
# - 📘 [Open Demo in Colab](https://colab.research.google.com/github/mithun-rk/mt-advml-course/blob/main/pyfiles/Day1_Block6_Demo_Evaluating_Models_Metrics_Tuning.ipynb)

# %% [markdown]
# ## Block 7 — Lab: Threshold Selection & Class Imbalance
#
# - 📝 [Open Lab (Starter) in Colab](https://colab.research.google.com/github/mithun-rk/mt-advml-course/blob/main/pyfiles/Day1_Block7_Lab_STARTER_Threshold_Class_Imbalance.ipynb)
# - ✅ [Open Lab (Solution) in Colab](https://colab.research.google.com/github/mithun-rk/mt-advml-course/blob/main/pyfiles/Day1_Block7_Lab_SOLUTION_Threshold_Class_Imbalance.ipynb)

# %% [markdown]
# ## Block 8 — Demo: Advanced Metrics — Tying It Together
#
# - 📘 [Open Demo in Colab](https://colab.research.google.com/github/mithun-rk/mt-advml-course/blob/main/pyfiles/Day1_Block8_Demo_Advanced_Metrics_Tietogether.ipynb)

# %% [markdown]
# ## Block 9 — Lab: Outlier Detection & Treatment
#
# - 📝 [Open Lab (Starter) in Colab](https://colab.research.google.com/github/mithun-rk/mt-advml-course/blob/main/pyfiles/Day1_Block9_Lab_STARTER_Outlier_Detection_Treatment.ipynb)
# - ✅ [Open Lab (Solution) in Colab](https://colab.research.google.com/github/mithun-rk/mt-advml-course/blob/main/pyfiles/Day1_Block9_Lab_SOLUTION_Outlier_Detection_Treatment.ipynb)

# %% [markdown]
# ## Block 10 — Demo: Outlier Partitioning & Wrap-Up
#
# - 📘 [Open Demo in Colab](https://colab.research.google.com/github/mithun-rk/mt-advml-course/blob/main/pyfiles/Day1_Block10_Demo_Outlier_Partitioning_Day1_Wrap.ipynb)

# %% [markdown]
# ## Block 12 — Demo: Ensembles — Random Forests & Gradient Boosted Trees
#
# - 📘 [Open Demo in Colab](https://colab.research.google.com/github/mithun-rk/mt-advml-course/blob/main/pyfiles/Day2_Block12_Demo_Ensembles_RF_GBT.ipynb)

# %% [markdown]
# ## Block 13 — Lab: Bagging
#
# - 📝 [Open Lab (Starter) in Colab](https://colab.research.google.com/github/mithun-rk/mt-advml-course/blob/main/pyfiles/Day2_Block13_Lab_STARTER_Bagging.ipynb)
# - ✅ [Open Lab (Solution) in Colab](https://colab.research.google.com/github/mithun-rk/mt-advml-course/blob/main/pyfiles/Day2_Block13_Lab_SOLUTION_Bagging.ipynb)

# %% [markdown]
# ## Block 14 — Demo: Heterogeneous Ensembles
#
# - 📘 [Open Demo in Colab](https://colab.research.google.com/github/mithun-rk/mt-advml-course/blob/main/pyfiles/Day2_Block14_Demo_Heterogeneous_Ensembles.ipynb)

# %% [markdown]
# ## Block 17 — Demo: Time Series — State & Sequence
#
# - 📘 [Open Demo in Colab](https://colab.research.google.com/github/mithun-rk/mt-advml-course/blob/main/pyfiles/Day2_Block17_Demo_TimeSeries_StateSequence.ipynb)

# %% [markdown]
# ## Block 18 — Lab: ARIMA
#
# - 📝 [Open Lab (Starter) in Colab](https://colab.research.google.com/github/mithun-rk/mt-advml-course/blob/main/pyfiles/Day2_Block18_Lab_STARTER_ARIMA.ipynb)
# - ✅ [Open Lab (Solution) in Colab](https://colab.research.google.com/github/mithun-rk/mt-advml-course/blob/main/pyfiles/Day2_Block18_Lab_SOLUTION_ARIMA.ipynb)

# %% [markdown]
# ## Block 19 — Demo: Time Series — RNN
#
# - 📘 [Open Demo in Colab](https://colab.research.google.com/github/mithun-rk/mt-advml-course/blob/main/pyfiles/Day2_Block19_Demo_TimeSeries_RNN.ipynb)

# %% [markdown]
# ---
#
# ### Notes
# - All notebooks and datasets are hosted in a public GitHub repository (`mithun-rk/mt-advml-course`) for the duration of the course.
# - Links point to the `main` branch — avoid pushing changes to the repo during class hours, since a Colab tab already open won't pick up a later edit.
